# %% [markdown]
# ### Imports

# %%
import warnings
warnings.filterwarnings("ignore")

# !pwd
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir('/content/drive/My Drive/DSCI565_HW/Project/')
# !pwd
# Out:
# /content/drive/MyDrive/DSCI565_HW/Project
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/DSCI565_HW/Project

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !pip install yfinance
import yfinance as yf

symbol = 'GOOGL'  # change as needed
start_date = '2009-01-01'
end_date = '2023-11-18'
df = yf.download(symbol, start=start_date, end=end_date)
df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2009-01-02    7.722723    8.053554    7.645145    8.041041    8.041041
# 2009-01-05    8.033033    8.289289    7.882883    8.209459    8.209459
# 2009-01-06    8.332833    8.528529    8.167918    8.359860    8.359860
# 2009-01-07    8.216216    8.281031    7.976727    8.058308    8.058308
# 2009-01-08    7.964965    8.137888    7.941441    8.137888    8.137888
# ...                ...         ...         ...         ...         ...
# 2023-11-13  131.779999  132.589996  131.250000  132.089996  132.089996
# 2023-11-14  134.190002  135.699997  133.320007  133.619995  133.619995
# 2023-11-15  134.869995  135.029999  133.570007  134.619995  134.619995
# 2023-11-16  135.190002  137.220001  134.320007  136.929993  136.929993
# 2023-11-17  136.000000  136.059998  133.649994  135.309998  135.309998
#
#                Volume
# Date
# ...

# %%
# !pip install pytrends
from pytrends import dailydata
from datetime import datetime
from datetime import timedelta
from datetime import datetime

# %%
years = []
months = []

# Change date range as required
for year in range(2009, 2024):
    for month in range(1, 13):
        years.append(year)
        months.append(month)

df_ym = pd.DataFrame({'Year': years, 'Month': months})

def get_start_end_dates(row):
    start_date = pd.Timestamp(f"{row['Year']}-{row['Month']}-01")
    end_date = start_date + pd.offsets.MonthEnd(0)
    return start_date, end_date

df_ym[['Start_Date', 'End_Date']] = df_ym.apply(get_start_end_dates, axis=1, result_type='expand')

df_dates = df_ym.copy()
df_dates
# Out:
#      Year  Month Start_Date   End_Date
# 0    2009      1 2009-01-01 2009-01-31
# 1    2009      2 2009-02-01 2009-02-28
# 2    2009      3 2009-03-01 2009-03-31
# 3    2009      4 2009-04-01 2009-04-30
# 4    2009      5 2009-05-01 2009-05-31
# ..    ...    ...        ...        ...
# 175  2023      8 2023-08-01 2023-08-31
# 176  2023      9 2023-09-01 2023-09-30
# 177  2023     10 2023-10-01 2023-10-31
# 178  2023     11 2023-11-01 2023-11-30
# 179  2023     12 2023-12-01 2023-12-31
#
# [180 rows x 4 columns]

# %%
start_date_list = df_dates['Start_Date'].tolist()
# start_date_list

end_date_list = df_dates['End_Date'].tolist()
# end_date_list

# %%
from pytrends.request import TrendReq
import pandas as pd
import time
pytrend = TrendReq()

df_dates = pd.DataFrame({"Start_Date": start_date_list, "End_Date": end_date_list})

interest_over_time_df = pd.DataFrame()

pytrends = TrendReq(hl='en-US', tz=360)


for k in range(len(df_dates)):
    start_date = str(df_dates[["Start_Date", "End_Date"]].iloc[k][0])[:10]
    end_date = str(df_dates[["Start_Date", "End_Date"]].iloc[k][1])[:10]
    print(start_date, end_date)

    success = False
    while not success:
        try:
            if(start_date == '2023-12-01'):
              break
            pytrend.build_payload(kw_list=[symbol], timeframe=f'{start_date} {end_date}')
            interest_over_time_df = interest_over_time_df.append(pytrend.interest_over_time())
            success = True
        except Exception as e:
            print(f"Future Date Accessed: {e}")
            print("Retrying...")
            time.sleep(5)

interest_over_time_df
# Out:
# 2009-01-01 2009-01-31
# 2009-02-01 2009-02-28
# 2009-03-01 2009-03-31
# 2009-04-01 2009-04-30
# 2009-05-01 2009-05-31
# 2009-06-01 2009-06-30
# 2009-07-01 2009-07-31
# 2009-08-01 2009-08-31
# 2009-09-01 2009-09-30
# 2009-10-01 2009-10-31
# 2009-11-01 2009-11-30
# 2009-12-01 2009-12-31
# 2010-01-01 2010-01-31
# 2010-02-01 2010-02-28
# 2010-03-01 2010-03-31
# 2010-04-01 2010-04-30
# 2010-05-01 2010-05-31
# 2010-06-01 2010-06-30
# 2010-07-01 2010-07-31
# 2010-08-01 2010-08-31
# 2010-09-01 2010-09-30
# 2010-10-01 2010-10-31
# 2010-11-01 2010-11-30
# 2010-12-01 2010-12-31
# 2011-01-01 2011-01-31
# 2011-02-01 2011-02-28
# 2011-03-01 2011-03-31
# 2011-04-01 2011-04-30
# 2011-05-01 2011-05-31
# 2011-06-01 2011-06-30
# 2011-07-01 2011-07-31
# 2011-08-01 2011-08-31
# 2011-09-01 2011-09-30
# 2011-10-01 2011-10-31
# 2011-11-01 2011-11-30
# 2011-12-01 2011-12-31
# 2012-01-01 2012-01-31
# 2012-02-01 2012-02-29
# 2012-03-01 2012-03-31
# 2012-04-01 2012-04-30
# 2012-05-01 2012-05-31
# ...

# %%
interest_over_time_df.rename(columns={symbol : 'Search_Trend'}, inplace = True)
interest_over_time_df = interest_over_time_df[['Search_Trend']]
interest_over_time_df

# interest_over_time_df.to_csv('Google_Trends.csv')
# Out:
#             Search_Trend
# date
# 2009-01-01            59
# 2009-01-02            68
# 2009-01-03            67
# 2009-01-04            61
# 2009-01-05            63
# ...                  ...
# 2023-11-25            60
# 2023-11-26            66
# 2023-11-27            98
# 2023-11-28            92
# 2023-11-29            92
#
# [5446 rows x 1 columns]

# %%
# interest_over_time_df = pd.read_csv('Google_Trends.csv')
# interest_over_time_df

# interest_over_time_df.set_index('date', inplace=True)
# interest_over_time_df

# %%
interest_over_time_df.index.name='Date'
interest_over_time_df[:]
# Out:
#             Search_Trend
# Date
# 2009-01-01            59
# 2009-01-02            68
# 2009-01-03            67
# 2009-01-04            61
# 2009-01-05            63
# ...                  ...
# 2023-11-25            60
# 2023-11-26            66
# 2023-11-27            98
# 2023-11-28            92
# 2023-11-29            92
#
# [5446 rows x 1 columns]

# %%
interest_over_time_df.index = pd.to_datetime(interest_over_time_df.index)
df.index.dtype, interest_over_time_df.index.dtype
# Out:
# (dtype('<M8[ns]'), dtype('<M8[ns]'))

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2009-01-02    7.722723    8.053554    7.645145    8.041041    8.041041
# 2009-01-05    8.033033    8.289289    7.882883    8.209459    8.209459
# 2009-01-06    8.332833    8.528529    8.167918    8.359860    8.359860
# 2009-01-07    8.216216    8.281031    7.976727    8.058308    8.058308
# 2009-01-08    7.964965    8.137888    7.941441    8.137888    8.137888
# ...                ...         ...         ...         ...         ...
# 2023-11-13  131.779999  132.589996  131.250000  132.089996  132.089996
# 2023-11-14  134.190002  135.699997  133.320007  133.619995  133.619995
# 2023-11-15  134.869995  135.029999  133.570007  134.619995  134.619995
# 2023-11-16  135.190002  137.220001  134.320007  136.929993  136.929993
# 2023-11-17  136.000000  136.059998  133.649994  135.309998  135.309998
#
#                Volume
# Date
# 2009-01-02  144275580
# 2009-01-05  195364440
# 2009-01-06  256750992
# ...

# %%
data = pd.merge(df, interest_over_time_df, how=str('left'), on='Date')
data

data.reset_index(inplace=True)
data.to_csv('Price_SearchTrend.csv')

# %%
data[data['Search_Trend'].isna()]
data
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2009-01-02    7.722723    8.053554    7.645145    8.041041    8.041041
# 1    2009-01-05    8.033033    8.289289    7.882883    8.209459    8.209459
# 2    2009-01-06    8.332833    8.528529    8.167918    8.359860    8.359860
# 3    2009-01-07    8.216216    8.281031    7.976727    8.058308    8.058308
# 4    2009-01-08    7.964965    8.137888    7.941441    8.137888    8.137888
# ...         ...         ...         ...         ...         ...         ...
# 3741 2023-11-13  131.779999  132.589996  131.250000  132.089996  132.089996
# 3742 2023-11-14  134.190002  135.699997  133.320007  133.619995  133.619995
# 3743 2023-11-15  134.869995  135.029999  133.570007  134.619995  134.619995
# 3744 2023-11-16  135.190002  137.220001  134.320007  136.929993  136.929993
# 3745 2023-11-17  136.000000  136.059998  133.649994  135.309998  135.309998
#
#          Volume  Search_Trend
# ...
